# %% [markdown]
# # Preface

# %% [markdown]
# The main code of CGSB was created independently from insane, but the lipid, solvent and protein definitions used in insane have been converted to the new CGSB data format.
#
# The program is still under active development so certain features may not have been fully implemented yet and there may be bugs. Please report any bugs you find.

# %% [markdown]
# # Basic System

# %%
import CGSB
''' Basic system

Contains a symmetric membrane composed entirely of POPC

The system is solvated using default molarities for water (55.56 mol/L), with an ion concentration of 0.15 mol/L using potassium ions and chloride ions
'''

sysname = "BasicSystem"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### From script:
CGSB.CGSB(
    box = [10, 10, 10],
    
    membrane = "POPC",
    
    solvation = "", # if no command is given to solvation, then it defaults to "solv:W pos:NA neg:CL"
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# Time spent importing packages: 4.5204
#
# Setting random seed to: 1697446077
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 22
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 3
#     Number of negative ions preprocessed: 9
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Number of membranes preprocessed: 1
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Number of solvent commands preprocessed: 1
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0009 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.0002 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.0
#             Average: 0.0
#             Minimum: 0.0
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 167          : 100.0   : 100.0      : 100.0      : 167
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.0
#             Average: 0.0
#             Minimum: 0.0
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 167          : 100.0   : 100.0      : 100.0      : 167
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             POPC       : 334          : 100.0
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0004 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0257 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0334 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.0672 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.0685 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             1000.0
#         Lipid volume:           308.907
#         Protein volume:         0
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        308.907
#         Free volume:            691.093
#         Solvent volume:         693.933
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 241057
#     Inserting 5904 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         W    : 5780   : 97.9    : 9.598         : 13.888         : 13.831            : 0
#         NA   : 62     : 1.05    : 0.103         : 0.149          : 0.148             : 1
#         CL   : 62     : 1.05    : 0.103         : 0.149          : 0.148             : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 0.3764 [s])
#
# --------------------
# Final system charge: 0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/BasicSystem/output_BasicSystem.pdb
# ---- GRO file written: output_test_systems/BasicSystem/output_BasicSystem.gro
#
# Writing topology file: output_test_systems/BasicSystem/topol_BasicSystem.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/BasicSystem/log_BasicSystem.log
# ---- Log file written
#
# My task is complete. Did i do a good job?

# %% [markdown]
# # Simple System

# %%
import CGSB
''' Simple system

Contains a symmetric membrane composed of POPC and CHOL in a 5:1 ratio

The system is solvated using default molarities for water (55.56 mol/L), with an ion concentration of 0.15 mol/L using potassium ions and chloride ions

Charge data is gathered from the "top_for_CGSB.itp"
'''

sysname = "SimpleSystem"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### From script:
CGSB.CGSB(
    box = [10, 10, 10],
    
    membrane = "POPC:5 CHOL:1",
    
    solvation = "",
    
    itp_input = "top_for_CGSB.itp",
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# Setting random seed to: 1697446078
#
# Loading topology file(s)
#     Finished loading topologies. Number of moleculetypes found: 221
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 22
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 3
#     Number of negative ions preprocessed: 9
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Number of membranes preprocessed: 1
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Number of solvent commands preprocessed: 1
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0006 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.0001 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             POPC       : 278          : 83.234
#             CHOL       : 56           : 16.766
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0004 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0417 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0312 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.0804 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.0643 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             1000.0
#         Lipid volume:           291.643
#         Protein volume:         0
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        291.643
#         Free volume:            708.357
#         Solvent volume:         711.342
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 242638
#     Inserting 6053 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         W    : 5925   : 97.885  : 9.839         : 13.889         : 13.831            : 0
#         NA   : 64     : 1.057   : 0.106         : 0.15           : 0.149             : 1
#         CL   : 64     : 1.057   : 0.106         : 0.15           : 0.149             : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 0.3015 [s])
#
# --------------------
# Final system charge: 0.0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/SimpleSystem/output_SimpleSystem.pdb
# ---- GRO file written: output_test_systems/SimpleSystem/output_SimpleSystem.gro
#
# Writing topology file: output_test_systems/SimpleSystem/topol_SimpleSystem.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/SimpleSystem/log_SimpleSystem.log
# ---- Log file written
#
# My task is complete. Did i do a good job?

# %% [markdown]
# # System With Protein

# %%
import CGSB
''' System With Protein

Contains a symmetric membrane composed of POPC and CHOL in a 4.7:1.3 ratio with an APL of 0.536
causing more lipids to be placed in the membrane than with the default APL of 0.6

A protein is inserted at the center of the system with its topology name being "PROT_1"
### Change protein.pdb to be your protein
### Chain PROT_1 to be the mol_name in you .itp file

The system is solvated using default molarities for water (55.56 mol/L), with an ion concentration of 0.15 mol/L using potassium ions and chloride ions

Charge data is gathered from the "top_for_CGSB.itp" file

Written files are given custom names and a log file is written
'''

sysname = "SystemWithProtein"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### From script:
CGSB.CGSB(
    box = [10, 10, 10],
    
    protein = "example_proteins/PDB_8BB6_martinized.pdb mol_names:8BB6_CG",
    
    membrane = "apl:0.536 POPC:4.7 CHOL:1.3",
    
    solvation = "",
    
    itp_input = "top_for_CGSB.itp",
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# Setting random seed to: 1697446079
#
# Loading topology file(s)
#     Finished loading topologies. Number of moleculetypes found: 221
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 22
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 3
#     Number of negative ions preprocessed: 9
#
# Preprocessing protein requests
#     Starting protein: 1
#     Number of molecule insertions preprocessed: 1
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Number of membranes preprocessed: 1
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Number of solvent commands preprocessed: 1
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ PROTEIN PLACEMENT
# Starting protein nr 1
#     Centering protein using 'cog' at x/y/z: 0.0 -0.0 0.0 (Input file coordinate system [Å])
#     New protein center at x/y/z: 0 0 0 (Internal coordinate system [Å])
#     Finished placing protein nr 1
# ------------------------------ PLACEMENT COMPLETE (time spent: 0.0085 [s])
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.536nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.536nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0006 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#     Finding protein beads inside leaflets
#         Starting upper leaflet
#             Leaflet-protein overlap found for 450 protein beads
#         Starting lower leaflet
#             Leaflet-protein overlap found for 469 protein beads
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.2411 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.187
#             Average: 0.187
#             Minimum: 0.187
#         Leaflet specific lipid data (Max lipids: 151, Final lipids: 151)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 118          : 78.146  : 78.333     : 78.667     : 118
#             CHOL       : 33           : 21.854  : 21.667     : 21.333     : 32
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.044
#             Average: 0.044
#             Minimum: 0.044
#         Leaflet specific lipid data (Max lipids: 153, Final lipids: 152)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 119          : 78.289  : 78.333     : 78.289     : 119
#             CHOL       : 33           : 21.711  : 21.667     : 21.711     : 33
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             POPC       : 237          : 78.218
#             CHOL       : 66           : 21.782
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0004 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0445 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0453 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.1291 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.0497 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             1000.0
#         Lipid volume:           259.889
#         Protein volume:         84.163
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        428.216
#         Free volume:            571.784
#         Solvent volume:         574.116
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 220778
#     Inserting 4900 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         W    : 4782   : 97.592  : 7.941         : 13.888         : 13.831            : 0
#         NA   : 51     : 1.041   : 0.085         : 0.148          : 0.148             : 1
#         CL   : 67     : 1.367   : 0.111         : 0.195          : 0.194             : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 0.3087 [s])
#
# --------------------
# Final system charge: 0.0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/SystemWithProtein/output_SystemWithProtein.pdb
# ---- GRO file written: output_test_systems/SystemWithProtein/output_SystemWithProtein.gro
#
# Writing topology file: output_test_systems/SystemWithProtein/topol_SystemWithProtein.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/SystemWithProtein/log_SystemWithProtein.log
# ---- Log file written
#
# My task is complete. Did i do a good job?

# %% [markdown]
# # Asymmetric Membrane System

# %%
import CGSB
''' Asymmetric Membrane System

Contains an asymmetric membrane
- The upper leaflet is composed of POPC and CHOL in a 4.7:1.3 ratio with an APL of 0.573 and
- The lower leaflet is composed of POPC and CHOL in a 3.8:2.8 ratio with an APL of 0.487 and
- The APLs will cause the lower leaflet to contain more lipids than the upper one

The system is solvated using default molarities for water (55.56 mol/L), with an ion concentration of 0.15 mol/L using potassium ions and chloride ions

Charge data is gathered from the "top_for_CGSB.itp" file
'''

sysname = "AsymmetricMembraneSystem"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### From script:
CGSB.CGSB(
    box = [10, 10, 10],
    
    membrane = "leaflet:upper apl:0.573 POPC:4.7 CHOL:1.3 leaflet:lower apl:0.487 POPC:3.8 CHOL:2.8",
    
    solvation = "",
    
    itp_input = "top_for_CGSB.itp",
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# Setting random seed to: 1697446080
#
# Loading topology file(s)
#     Finished loading topologies. Number of moleculetypes found: 221
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 22
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 3
#     Number of negative ions preprocessed: 9
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Number of membranes preprocessed: 1
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Number of solvent commands preprocessed: 1
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.573nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.48699999999999993nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0006 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.0001 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.105
#             Average: 0.105
#             Minimum: 0.105
#         Leaflet specific lipid data (Max lipids: 175, Final lipids: 174)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 100          : 57.471  : 57.576     : 57.471     : 100
#             CHOL       : 74           : 42.529  : 42.424     : 42.529     : 74
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.015
#             Average: 0.015
#             Minimum: 0.015
#         Leaflet specific lipid data (Max lipids: 205, Final lipids: 205)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 118          : 57.561  : 57.576     : 57.843     : 118
#             CHOL       : 87           : 42.439  : 42.424     : 42.157     : 86
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             POPC       : 218          : 57.52
#             CHOL       : 161          : 42.48
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0005 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0273 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0354 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.0712 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.0664 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             1000.0
#         Lipid volume:           300.892
#         Protein volume:         0
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        300.892
#         Free volume:            699.108
#         Solvent volume:         701.977
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 243260
#     Inserting 5973 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         W    : 5847   : 97.891  : 9.709         : 13.888         : 13.831            : 0
#         NA   : 63     : 1.055   : 0.105         : 0.15           : 0.149             : 1
#         CL   : 63     : 1.055   : 0.105         : 0.15           : 0.149             : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 0.3058 [s])
#
# --------------------
# Final system charge: 0.0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/AsymmetricMembraneSystem/output_AsymmetricMembraneSystem.pdb
# ---- GRO file written: output_test_systems/AsymmetricMembraneSystem/output_AsymmetricMembraneSystem.gro
#
# Writing topology file: output_test_systems/AsymmetricMembraneSystem/topol_AsymmetricMembraneSystem.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/AsymmetricMembraneSystem/log_AsymmetricMembraneSystem.log
# ---- Log file written
#
# My task is complete. Did i do a good job?

# %% [markdown]
# # Phase Separated System

# %%
import CGSB
''' Phase Separated System

Contains phase separated membrane constructed from 4 separate membrane commands

The system is solvated using default molarities for water (55.56 mol/L), with an ion concentration of 0.15 mol/L using potassium ions and chloride ions

Charge data is gathered from the "top_for_CGSB.itp" file
'''

sysname = "PhaseSeparatedSystem"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### From script:
CGSB.CGSB(
    box = [20, 20, 10],
    
    membrane = [
        ### center:x:y:z
        "DPPC:5 CHOL:1 center:-5:-5:0 x:10 y:10", # bottom left
        "DOPC:5 CHOL:1 center:5:-5:0 x:10 y:10",  # bottom right
        "DOPC:5 CHOL:1 center:-5:5:0 x:10 y:10",  # top left
        "DPPC:5 CHOL:1 center:5:5:0 x:10 y:10",   # top right
        
        ### Results in 5:5:2 DPPC:DOPC:CHOL distribution
    ],
    
    solvation = "",
    
    itp_input = "top_for_CGSB.itp",
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# Setting random seed to: 1697446082
#
# Loading topology file(s)
#     Finished loading topologies. Number of moleculetypes found: 221
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 22
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 3
#     Number of negative ions preprocessed: 9
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Starting membrane command: 2
#     Starting membrane command: 3
#     Starting membrane command: 4
#     Number of membranes preprocessed: 4
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Number of solvent commands preprocessed: 1
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#
# Starting membrane nr 2
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#
# Starting membrane nr 3
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#
# Starting membrane nr 4
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0018 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 2
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 3
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 4
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.0004 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
# Starting membrane nr 2
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
# Starting membrane nr 3
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
# Starting membrane nr 4
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             DPPC       : 556          : 41.617
#             CHOL       : 224          : 16.766
#             DOPC       : 556          : 41.617
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0016 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0365 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0251 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 2
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0418 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0314 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 3
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0437 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.032 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 4
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0366 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0281 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.3102 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 2
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 3
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 4
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.2974 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             4000.0
#         Lipid volume:           1166.572
#         Protein volume:         0
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        1166.572
#         Free volume:            2833.428
#         Solvent volume:         2845.367
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 982692
#     Inserting 24214 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         W    : 23700  : 97.877  : 9.839         : 13.889         : 13.831            : 0
#         NA   : 257    : 1.061   : 0.107         : 0.151          : 0.15              : 1
#         CL   : 257    : 1.061   : 0.107         : 0.151          : 0.15              : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 1.2856 [s])
#
# --------------------
# Final system charge: 0.0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/PhaseSeparatedSystem/output_PhaseSeparatedSystem.pdb
# ---- GRO file written: output_test_systems/PhaseSeparatedSystem/output_PhaseSeparatedSystem.gro
#
# Writing topology file: output_test_systems/PhaseSeparatedSystem/topol_PhaseSeparatedSystem.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/PhaseSeparatedSystem/log_PhaseSeparatedSystem.log
# ---- Log file written
#
# My task is complete. Did i do a good job?

# %% [markdown]
# # Phase Separated System Generator

# %%
import CGSB
import numpy as np
import math
''' Phase Separated System Generator

Contains phase separated membrane constructed from a number of coloumns and rows

The system is solvated using default molarities for water (55.56 mol/L), with an ion concentration of 0.15 mol/L using potassium ions and chloride ions

Charge data is gathered from the "top_for_CGSB.itp" file
'''

sysname = "PhaseSeparatedSystemGenerator"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### ### Initial settings:
box = [20, 20, 10]
xrows = 5
yrows = 3
### ###

xmin, xmax = -box[0]/2, box[0]/2
ymin, ymax = -box[1]/2, box[1]/2

xlen = round(box[0]/xrows, 3)
ylen = round(box[1]/yrows, 3)

xcenters = np.linspace(xmin+(xlen/2), xmax-(xlen/2), num=xrows, endpoint=True)
ycenters = np.linspace(ymin+(ylen/2), ymax-(ylen/2), num=yrows, endpoint=True)

centers = [(round(x,3), round(y,3)) for x in xcenters for y in ycenters]
lipids = []
memb_commands = []
DPPC_counter = 0
DOPC_counter = 0
for i, (x, y) in enumerate(centers):
    if i % 2 == 0:
        lipid = "DPPC"
        DPPC_counter += 1
    else:
        lipid = "DOPC"
        DOPC_counter += 1
    memb_commands.append(lipid+":5 CHOL:1 center:"+str(x)+":"+str(y)+":0 x:"+str(xlen) + " y:"+str(ylen) )

counter_sum = DPPC_counter + DOPC_counter
DPPC_tot_ratio = 5*DPPC_counter
DOPC_tot_ratio = 5*DOPC_counter
CHOL_tot_ratio = counter_sum
GCD = math.gcd(DPPC_tot_ratio, DOPC_tot_ratio, CHOL_tot_ratio)
print("DPPC patches:", DPPC_counter)
print("DOPC patches:", DOPC_counter)
print(
    "Final DPPC:DOPC:CHOL system ratio:",
    ":".join([
        str(DPPC_tot_ratio//GCD),
        str(DOPC_tot_ratio//GCD),
        str(CHOL_tot_ratio//GCD),
    ])
)
print("Membrane commands:")
for memb_command in memb_commands:
    print("    ", memb_command)

## From script:
CGSB.CGSB(
    box = box,
    
    membrane = memb_commands,
    
    solvation = "",
    
    itp_input = "top_for_CGSB.itp",
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# DPPC patches: 8
# DOPC patches: 7
# Final DPPC:DOPC:CHOL system ratio: 8:7:3
# Membrane commands:
#      DPPC:5 CHOL:1 center:-8.0:-6.666:0 x:4.0 y:6.667
#      DOPC:5 CHOL:1 center:-8.0:0.0:0 x:4.0 y:6.667
#      DPPC:5 CHOL:1 center:-8.0:6.666:0 x:4.0 y:6.667
#      DOPC:5 CHOL:1 center:-4.0:-6.666:0 x:4.0 y:6.667
#      DPPC:5 CHOL:1 center:-4.0:0.0:0 x:4.0 y:6.667
#      DOPC:5 CHOL:1 center:-4.0:6.666:0 x:4.0 y:6.667
#      DPPC:5 CHOL:1 center:0.0:-6.666:0 x:4.0 y:6.667
#      DOPC:5 CHOL:1 center:0.0:0.0:0 x:4.0 y:6.667
#      DPPC:5 CHOL:1 center:0.0:6.666:0 x:4.0 y:6.667
#      DOPC:5 CHOL:1 center:4.0:-6.666:0 x:4.0 y:6.667
#      DPPC:5 CHOL:1 center:4.0:0.0:0 x:4.0 y:6.667
#      DOPC:5 CHOL:1 center:4.0:6.666:0 x:4.0 y:6.667
#      DPPC:5 CHOL:1 center:8.0:-6.666:0 x:4.0 y:6.667
#      DOPC:5 CHOL:1 center:8.0:0.0:0 x:4.0 y:6.667
#      DPPC:5 CHOL:1 center:8.0:6.666:0 x:4.0 y:6.667
#
# Setting random seed to: 1697446085
#
# Loading topology file(s)
#     Finished loading topologies. Number of moleculetypes found: 221
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 22
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 3
#     Number of negative ions preprocessed: 9
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Starting membrane command: 2
#     Starting membrane command: 3
#     Starting membrane command: 4
#     Starting membrane command: 5
#     Starting membrane command: 6
#     Starting membrane command: 7
#     Starting membrane command: 8
#     Starting membrane command: 9
#     Starting membrane command: 10
#     Starting membrane command: 11
#     Starting membrane command: 12
#     Starting membrane command: 13
#     Starting membrane command: 14
#     Starting membrane command: 15
#     Number of membranes preprocessed: 15
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Number of solvent commands preprocessed: 1
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 2
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 3
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 4
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 5
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 6
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 7
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 8
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 9
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 10
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 11
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 12
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 13
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 14
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#
# Starting membrane nr 15
#     Starting upper leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=4.0nm y=6.667nm APL=0.6nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0048 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 2
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 3
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 4
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 5
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 6
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 7
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 8
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 9
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 10
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 11
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 12
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 13
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 14
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
#
# Starting membrane nr 15
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.0012 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 2
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 3
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 4
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 5
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 6
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 7
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 8
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 9
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 10
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 11
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 12
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 13
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 14
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DOPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Starting membrane nr 15
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.388
#             Average: 0.388
#             Minimum: 0.388
#         Leaflet specific lipid data (Max lipids: 44, Final lipids: 43)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             DPPC       : 36           : 83.721  : 83.333     : 83.721     : 36
#             CHOL       : 7            : 16.279  : 16.667     : 16.279     : 7
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             DPPC       : 576          : 44.651
#             CHOL       : 210          : 16.279
#             DOPC       : 504          : 39.07
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0046 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0107 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0103 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 2
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0103 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0106 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 3
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0104 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0065 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 4
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.008 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0082 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 5
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0063 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0065 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 6
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0064 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0063 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 7
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0066 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0081 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 8
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0064 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0064 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 9
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0068 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0064 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 10
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0105 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0161 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 11
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0099 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.01 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 12
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0097 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0097 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 13
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0077 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0063 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 14
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0078 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0061 [s]
#             Mean step time:     0.0 [s]
#
# Starting membrane nr 15
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0061 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0061 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.2907 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 2
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 3
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 4
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 5
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 6
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 7
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 8
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 9
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 10
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 11
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 12
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 13
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 14
#     Starting upper leaflet
#     Starting lower leaflet
# Starting membrane nr 15
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.2183 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             4000.0
#         Lipid volume:           1128.344
#         Protein volume:         0
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        1128.344
#         Free volume:            2871.656
#         Solvent volume:         2883.786
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 984247
#     Inserting 24540 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         W    : 24020  : 97.881  : 9.972         : 13.89          : 13.831            : 0
#         NA   : 260    : 1.059   : 0.108         : 0.15           : 0.15              : 1
#         CL   : 260    : 1.059   : 0.108         : 0.15           : 0.15              : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 1.3738 [s])
#
# --------------------
# Final system charge: 0.0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/PhaseSeparatedSystemGenerator/output_PhaseSeparatedSystemGenerator.pdb
# ---- GRO file written: output_test_systems/PhaseSeparatedSystemGenerator/output_PhaseSeparatedSystemGenerator.gro
#
# Writing topology file: output_test_systems/PhaseSeparatedSystemGenerator/topol_PhaseSeparatedSystemGenerator.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/PhaseSeparatedSystemGenerator/log_PhaseSeparatedSystemGenerator.log
# ---- Log file written
#
# My task is complete. Did i do a good job?

# %% [markdown]
# # Mixed Solvent System

# %%
import CGSB
''' Mixed solvent system

Contains a symmetric membrane composed of POPC and CHOL in a 5:1 ratio

The system is solvated using default molarities for water (55.56 mol/L), with an ion concentration of 0.15 mol/L using potassium ions and chloride ions
- The system contains a 5:3 ratio of regular water "W" to small water "SW"
- The system contains a 5:1 ratio of potassium ions to calcium ions
- The system's only negative ion is chloride
- The weighted number of positive ions (potassium and calcium) is equal to the weighted number of negative ions (chloride)
    - Weighting is done based on their charges, such that the charge sum equals zero

Charge data is gathered from the "top_for_CGSB.itp" file
'''

sysname = "MixedSolventSystem"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### From script:
CGSB.CGSB(
    box = [10, 10, 10],
    
    membrane = "POPC:5 CHOL:1",
    
    solvation = "solv:W:5 solv:SW:3 pos:NA:5 pos:CA:1 neg:CL:1",
    
    itp_input = "top_for_CGSB.itp",
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# Setting random seed to: 1697446088
#
# Loading topology file(s)
#     Finished loading topologies. Number of moleculetypes found: 221
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 22
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 3
#     Number of negative ions preprocessed: 9
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Number of membranes preprocessed: 1
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Number of solvent commands preprocessed: 1
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0006 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.0001 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.099
#             Average: 0.099
#             Minimum: 0.099
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 139          : 83.234  : 83.333     : 83.735     : 139
#             CHOL       : 28           : 16.766  : 16.667     : 16.265     : 27
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             POPC       : 278          : 83.234
#             CHOL       : 56           : 16.766
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0005 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0375 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0376 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.0823 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.0559 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             1000.0
#         Lipid volume:           291.643
#         Protein volume:         0
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        291.643
#         Free volume:            708.357
#         Solvent volume:         1422.684
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 242768
#     Inserting 14465 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         SW   : 7900   : 54.615  : 13.118        : 18.519         : 9.221             : 0
#         W    : 5925   : 40.961  : 9.839         : 13.889         : 6.916             : 0
#         CA   : 128    : 0.885   : 0.213         : 0.3            : 0.149             : 2
#         NA   : 128    : 0.885   : 0.213         : 0.3            : 0.149             : 1
#         CL   : 384    : 2.655   : 0.638         : 0.9            : 0.448             : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 0.6076 [s])
#
# --------------------
# Final system charge: 0.0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/MixedSolventSystem/output_MixedSolventSystem.pdb
# ---- GRO file written: output_test_systems/MixedSolventSystem/output_MixedSolventSystem.gro
#
# Writing topology file: output_test_systems/MixedSolventSystem/topol_MixedSolventSystem.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/MixedSolventSystem/log_MixedSolventSystem.log
# ---- Log file written
#
# My task is complete. Did i do a good job?

# %% [markdown]
# # Flooding System

# %%
import CGSB
''' Flooding with imported ligand system

Contains a symmetric membrane composed of POPC with the default APL of 0.6

A protein is inserted at the center of the system with its topology name being "PROT_1"

The system is flooded with 30 molecules of the of structure in example_solute_1.pdb
### ### Barebones command:
### solute_input = "SOLUTE.pdb mol:SOLUTE_name:SOLUTE_nres:SOLUTE_charge",
### ### Replace:
### Replace "SOLUTE.pdb" with your molecule file
### Replace SOLUTE_name with the name you want to refer to the ligand as in the flooding command (max 4 characters or 'resname')
### Replace SOLUTE_nres with the number of residues in the molecule
### Replace SOLUTE_charge with the charge of the ligand or the 'moleculetype' used in the topology file


The system is solvated using default molarities for water (55.56 mol/L),
with an ion concentration of 0.15 mol/L using potassium and chloride ions

Charge data is gathered from the "top_for_CGSB.itp" file
'''

sysname = "FloodingSystem"
test_outdir = "/".join(["output_test_systems", sysname])
# !mkdir -p {test_outdir}

### From script:
system = CGSB.CGSB(
    box = [10, 10, 11],
    
    membrane = "POPC",
    
    solute_input = "example_solutes/example_solute.pdb mol:solu:2:Ex_Sol",
    
    flooding = "solv:solu:30",
    
    solvation = "solv:W pos:NA neg:CL",
    
    itp_input = "top_for_CGSB.itp",
    
    out_sys = test_outdir + "/" + "_".join(["output", sysname]),
    out_top = test_outdir + "/" + "_".join(["topol", sysname]) + ".top",
    out_log = test_outdir + "/" + "_".join(["log", sysname]) + ".log",
    
    backup = False,
)
# Out:
# Setting random seed to: 1697446089
#
# Loading topology file(s)
#     Finished loading topologies. Number of moleculetypes found: 221
# ------------------------------ PREPROCESSING
# Preprocessing lipid definitions
#     Number of lipids preprocessed: 107
#
# Preprocessing solvent definitions
#     Number of solvents preprocessed: 23
#
# Preprocessing ion definitions
#     Number of positive ions preprocessed: 4
#     Number of negative ions preprocessed: 10
#
# Preprocessing membrane requests
#     Starting membrane command: 1
#     Number of membranes preprocessed: 1
#
# Preprocessing solvent requests
#     Starting Solvent command: 1
#     Starting Solvent command: 2
#     Number of solvent commands preprocessed: 2
# ------------------------------ PREPROCESSING COMPLETE
#
# ------------------------------ CREATING LEAFLET BOUNDARY BOXES
# Starting membrane nr 1
#     Starting upper leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
#     Starting lower leaflet
#         Base parameters: x=10.0nm y=10.0nm APL=0.6nm^2
# ------------------------------ LEAFLET BOUNDARY BOXES CREATED (time spent: 0.0006 [s])
#
# ------------------------------ CREATING HOLED BOUNDARY BOXES
# Starting membrane nr 1
#
#     Calculating holed boundary box
#         Starting upper leaflet
#         Starting lower leaflet
# ------------------------------ HOLED BOUNDARY BOXES CREATED (time spent: 0.0001 [s])
#
# ------------------------------ CALCULATING LIPID RATIOS
# Starting membrane nr 1
#     Starting upper leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.0
#             Average: 0.0
#             Minimum: 0.0
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 167          : 100.0   : 100.0      : 100.0      : 167
#
#     Starting lower leaflet
#         Lipid optimization 'lipid_optim' setting: avg_optimal
#             Optimizing based on the average deviation from expected ratios
#         Final deviations from expected ratios: Difference in %-values
#             Maximum: 0.0
#             Average: 0.0
#             Minimum: 0.0
#         Leaflet specific lipid data (Max lipids: 167, Final lipids: 167)
#             Lipid name : Final lipids : Final % : Expected % : Starting % : Starting lipids
#             POPC       : 167          : 100.0   : 100.0      : 100.0      : 167
#
# Lipid data for whole system
#             Lipid name : Total lipids : Total %
#             POPC       : 334          : 100.0
# ------------------------------ LIPID RATIO CALCULATIONS COMPLETE (time spent: 0.0004 [s])
#
# ------------------------------ CREATING LIPID GRID
# Starting membrane nr 1
#     Starting upper leaflet
#         Starting optimization
#             CURRENT STEP: 1 2
#             Last step:          2
#             Optimization time:  0.0248 [s]
#             Mean step time:     0.0 [s]
#
#     Starting lower leaflet
#         Starting optimization
#             CURRENT STEP: 1 2 3
#             Last step:          3
#             Optimization time:  0.0327 [s]
#             Mean step time:     0.0 [s]
# ------------------------------ LIPID GRID CREATED (time spent: 0.065 [s])
#
# ------------------------------ CREATING LIPIDS
# Starting membrane nr 1
#     Starting upper leaflet
#     Starting lower leaflet
# ------------------------------ LIPID CREATION COMPLETE (time spent: 0.0679 [s])
#
# ------------------------------ SOLVATING SYSTEM
# Starting solvation nr 1
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             1100.0
#         Lipid volume:           308.907
#         Protein volume:         0
#         (Prior) Solvent volume: 0.0
#         Excluded volume:        308.907
#         Free volume:            791.093
#         Solvent volume:         0
#
# WARNING: NOTE: Requested solvent is too large for the grid resolution. Adjusting grid resolution to prevent solvent molecule overlaps.
# WARNING: Original grid resolution was: 1.32
# WARNING: New grid resolution is:       9.895453501482384
#
# WARNING: NOTE: Kick is too large for grid resolution. Adjusting grid resolution to prevent solvent molecule overlaps.
# WARNING: Original grid resolution was: 9.895453501482384
# WARNING: Original kick was:            0.5
# WARNING: New grid resolution is:       10.495453501482384
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 324
#     Inserting 30 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Starting solvation nr 2
#     Calculating box volume: (all values in [nm^3])
#         Bead radius used for volume calculations 'bead_radius': 2.64 [Å]
#         Box volume:             1100.0
#         Lipid volume:           308.907
#         Protein volume:         0
#         (Prior) Solvent volume: 18.497
#         Excluded volume:        308.907
#         Free volume:            791.093
#         Solvent volume:         794.422
#
#     Calculating the number of available grid points
#     Final number of 3D grid points available for solvent placement: 270668
#     Inserting 6819 solvent molecules into random grid points:
#           Currently at solvent number: 0
#
# Solvent data for whole system
#         Name : Totals : Total % : Molarity(box) : Molarity(free) : Molarity(solvent) : Charge
#         solu : 30     : 0.438   : 0.045         : 0.063          : 0.063             : 2
#         W    : 6617   : 96.613  : 9.989         : 13.889         : 13.831            : 0
#         NA   : 71     : 1.037   : 0.107         : 0.149          : 0.148             : 1
#         CL   : 131    : 1.913   : 0.198         : 0.275          : 0.274             : -1
# ------------------------------ SOLVATION COMPLETE (time spent: 0.3495 [s])
#
# --------------------
# Final system charge: 0.0
# --------------------
#
# Writing structure files (PDB/GRO)
# ---- PDB file written: output_test_systems/FloodingSystem/output_FloodingSystem.pdb
# ---- GRO file written: output_test_systems/FloodingSystem/output_FloodingSystem.gro
#
# Writing topology file: output_test_systems/FloodingSystem/topol_FloodingSystem.top
# ---- Topology file written
#
# Writing log file file: output_test_systems/FloodingSystem/log_FloodingSystem.log
# ---- Log file written
#
# My task is complete. Did i do a good job?
